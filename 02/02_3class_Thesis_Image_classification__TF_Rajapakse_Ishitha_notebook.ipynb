# %% [markdown]
# #Recognition of Phlebology Diseases Based on Photographs

# %%
# !pip install opencv-python==4.5.5.64
# Out:
# Collecting opencv-python==4.5.5.64
#   Downloading opencv_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.5 MB)
#      |████████████████████████████████| 60.5 MB 62 kB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python==4.5.5.64) (1.21.6)
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed opencv-python-4.5.5.64

# %%
# !python --version
# Out:
# Python 3.7.13

# %%
# !apt install subversion
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'apt autoremove' to remove them.
# The following additional packages will be installed:
#   libapr1 libaprutil1 libserf-1-1 libsvn1
# Suggested packages:
#   db5.3-util libapache2-mod-svn subversion-tools
# The following NEW packages will be installed:
#   libapr1 libaprutil1 libserf-1-1 libsvn1 subversion
# 0 upgraded, 5 newly installed, 0 to remove and 42 not upgraded.
# Need to get 2,237 kB of archives.
# After this operation, 9,910 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libapr1 amd64 1.6.3-2 [90.9 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libaprutil1 amd64 1.6.1-2 [84.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libserf-1-1 amd64 1.3.9-6 [44.4 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsvn1 amd64 1.9.7-4ubuntu1 [1,183 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 subversion amd64 1.9.7-4ubuntu1 [834 kB]
# Fetched 2,237 kB in 1s (2,519 kB/s)
# Selecting previously unselected package libapr1:amd64.
# (Reading database ... 155203 files and directories currently installed.)
# Preparing to unpack .../libapr1_1.6.3-2_amd64.deb ...
# Unpacking libapr1:amd64 (1.6.3-2) ...
# Selecting previously unselected package libaprutil1:amd64.
# Preparing to unpack .../libaprutil1_1.6.1-2_amd64.deb ...
# Unpacking libaprutil1:amd64 (1.6.1-2) ...
# Selecting previously unselected package libserf-1-1:amd64.
# Preparing to unpack .../libserf-1-1_1.3.9-6_amd64.deb ...
# Unpacking libserf-1-1:amd64 (1.3.9-6) ...
# Selecting previously unselected package libsvn1:amd64.
# Preparing to unpack .../libsvn1_1.9.7-4ubuntu1_amd64.deb ...
# Unpacking libsvn1:amd64 (1.9.7-4ubuntu1) ...
# Selecting previously unselected package subversion.
# Preparing to unpack .../subversion_1.9.7-4ubuntu1_amd64.deb ...
# Unpacking subversion (1.9.7-4ubuntu1) ...
# Setting up libapr1:amd64 (1.6.3-2) ...
# Setting up libaprutil1:amd64 (1.6.1-2) ...
# Setting up libserf-1-1:amd64 (1.3.9-6) ...
# Setting up libsvn1:amd64 (1.9.7-4ubuntu1) ...
# Setting up subversion (1.9.7-4ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !svn checkout https://github.com/ishitharaj/newCVIdata/trunk/CVI_newdataset/
# Out:
# A    CVI_newdataset/square3class
# A    CVI_newdataset/square3class/1
# A    CVI_newdataset/square3class/1/0001cls1.jpg
# A    CVI_newdataset/square3class/1/0001cls2.jpg
# A    CVI_newdataset/square3class/1/0002cls1.jpg
# A    CVI_newdataset/square3class/1/0002cls2.jpg
# A    CVI_newdataset/square3class/1/0003cls1.jpg
# A    CVI_newdataset/square3class/1/0003cls2.jpg
# A    CVI_newdataset/square3class/1/0004cls1.jpg
# A    CVI_newdataset/square3class/1/0004cls2.jpg
# A    CVI_newdataset/square3class/1/0005cls1.jpg
# A    CVI_newdataset/square3class/1/0005cls2.jpg
# A    CVI_newdataset/square3class/1/0006cls1.jpg
# A    CVI_newdataset/square3class/1/0006cls2.jpg
# A    CVI_newdataset/square3class/1/0007cls1.jpg
# A    CVI_newdataset/square3class/1/0007cls2.jpg
# A    CVI_newdataset/square3class/1/0008cls1.jpg
# A    CVI_newdataset/square3class/1/0008cls2.jpg
# A    CVI_newdataset/square3class/1/0009cls1.jpg
# A    CVI_newdataset/square3class/1/0009cls2.jpg
# A    CVI_newdataset/square3class/1/0010cls1.jpg
# A    CVI_newdataset/square3class/1/0010cls2.jpg
# A    CVI_newdataset/square3class/1/0011cls1.jpg
# A    CVI_newdataset/square3class/1/0011cls2.jpg
# A    CVI_newdataset/square3class/1/0012cls1.jpg
# A    CVI_newdataset/square3class/1/0012cls2.jpg
# A    CVI_newdataset/square3class/1/0013cls1.jpg
# A    CVI_newdataset/square3class/1/0013cls2.jpg
# A    CVI_newdataset/square3class/1/0014cls1.jpg
# A    CVI_newdataset/square3class/1/0014cls2.jpg
# A    CVI_newdataset/square3class/1/0015cls1.jpg
# A    CVI_newdataset/square3class/1/0015cls2.jpg
# A    CVI_newdataset/square3class/1/0016cls1.jpg
# A    CVI_newdataset/square3class/1/0016cls2.jpg
# A    CVI_newdataset/square3class/1/0017cls1.jpg
# A    CVI_newdataset/square3class/1/0017cls2.jpg
# A    CVI_newdataset/square3class/1/0018cls1.jpg
# A    CVI_newdataset/square3class/1/0018cls2.jpg
# A    CVI_newdataset/square3class/1/0019cls1.jpg
# A    CVI_newdataset/square3class/1/0019cls2.jpg
# A    CVI_newdataset/square3class/1/0020cls1.jpg
# A    CVI_newdataset/square3class/1/0020cls2.jpg
# A    CVI_newdataset/square3class/1/0021cls1.jpg
# A    CVI_newdataset/square3class/1/0021cls2.jpg
# A    CVI_newdataset/square3class/1/0022cls1.jpg
# A    CVI_newdataset/square3class/1/0022cls2.jpg
# A    CVI_newdataset/square3class/1/0023cls1.jpg
# A    CVI_newdataset/square3class/1/0023cls2.jpg
# A    CVI_newdataset/square3class/1/0024cls1.jpg
# A    CVI_newdataset/square3class/1/0024cls2.jpg
# A    CVI_newdataset/square3class/1/0025cls1.jpg
# A    CVI_newdataset/square3class/1/0026cls1.jpg
# A    CVI_newdataset/square3class/1/0027cls1.jpg
# A    CVI_newdataset/square3class/1/0028cls1.jpg
# A    CVI_newdataset/square3class/1/0029cls1.jpg
# A    CVI_newdataset/square3class/1/0030cls1.jpg
# A    CVI_newdataset/square3class/1/0031cls1.jpg
# A    CVI_newdataset/square3class/1/0032cls1.jpg
# A    CVI_newdataset/square3class/1/0033cls1.jpg
# A    CVI_newdataset/square3class/1/0034cls1.jpg
# A    CVI_newdataset/square3class/1/0035cls1.jpg
# A    CVI_newdataset/square3class/2
# A    CVI_newdataset/square3class/2/0001cls3.jpg
# A    CVI_newdataset/square3class/2/0002cls3.jpg
# A    CVI_newdataset/square3class/2/0003cls3.jpg
# A    CVI_newdataset/square3class/2/0004cls3.jpg
# A    CVI_newdataset/square3class/2/0005cls3.jpg
# A    CVI_newdataset/square3class/2/0006cls3.jpg
# A    CVI_newdataset/square3class/2/0007cls3.jpg
# A    CVI_newdataset/square3class/2/0008cls3.jpg
# A    CVI_newdataset/square3class/2/0009cls3.jpg
# A    CVI_newdataset/square3class/2/0010cls3.jpg
# A    CVI_newdataset/square3class/2/0011cls3.jpg
# A    CVI_newdataset/square3class/2/0012cls3.jpg
# A    CVI_newdataset/square3class/2/0013cls3.jpg
# A    CVI_newdataset/square3class/2/0014cls3.jpg
# A    CVI_newdataset/square3class/2/0015cls3.jpg
# A    CVI_newdataset/square3class/2/0016cls3.jpg
# A    CVI_newdataset/square3class/2/0017cls3.jpg
# A    CVI_newdataset/square3class/2/0018cls3.jpg
# A    CVI_newdataset/square3class/2/0019cls3.jpg
# A    CVI_newdataset/square3class/2/0020cls3.jpg
# A    CVI_newdataset/square3class/2/0021cls3.jpg
# A    CVI_newdataset/square3class/2/0022cls3.jpg
# A    CVI_newdataset/square3class/2/0023cls3.jpg
# A    CVI_newdataset/square3class/2/0024cls3.jpg
# A    CVI_newdataset/square3class/2/0025cls3.jpg
# A    CVI_newdataset/square3class/2/0026cls3.jpg
# A    CVI_newdataset/square3class/2/0027cls3.jpg
# A    CVI_newdataset/square3class/2/0028cls3.jpg
# A    CVI_newdataset/square3class/2/0029cls3.jpg
# A    CVI_newdataset/square3class/2/0030cls3.jpg
# A    CVI_newdataset/square3class/2/0031cls3.jpg
# A    CVI_newdataset/square3class/2/0032cls3.jpg
# A    CVI_newdataset/square3class/2/0033cls3.jpg
# A    CVI_newdataset/square3class/2/0034cls3.jpg
# A    CVI_newdataset/square3class/2/0035cls3.jpg
# A    CVI_newdataset/square3class/2/0036cls3.jpg
# A    CVI_newdataset/square3class/2/0037cls3.jpg
# A    CVI_newdataset/square3class/2/0038cls3.jpg
# A    CVI_newdataset/square3class/2/0039cls3.jpg
# A    CVI_newdataset/square3class/2/0040cls3.jpg
# A    CVI_newdataset/square3class/2/0041cls3.jpg
# A    CVI_newdataset/square3class/2/0042cls3.jpg
# A    CVI_newdataset/square3class/2/0043cls3.jpg
# A    CVI_newdataset/square3class/2/0044cls3.jpg
# A    CVI_newdataset/square3class/2/0045cls3.jpg
# A    CVI_newdataset/square3class/2/0046cls3.jpg
# A    CVI_newdataset/square3class/2/0047cls3.jpg
# A    CVI_newdataset/square3class/2/0048cls3.jpg
# A    CVI_newdataset/square3class/2/0049cls3.jpg
# A    CVI_newdataset/square3class/2/0050cls3.jpg
# A    CVI_newdataset/square3class/2/0051cls3.jpg
# A    CVI_newdataset/square3class/2/0052cls3.jpg
# A    CVI_newdataset/square3class/2/0053cls3.jpg
# A    CVI_newdataset/square3class/2/0054cls3.jpg
# A    CVI_newdataset/square3class/2/0055cls3.jpg
# A    CVI_newdataset/square3class/2/0056cls3.jpg
# A    CVI_newdataset/square3class/2/0057cls3.jpg
# A    CVI_newdataset/square3class/3
# A    CVI_newdataset/square3class/3/0001cls4.jpg
# A    CVI_newdataset/square3class/3/0001cls5.jpg
# A    CVI_newdataset/square3class/3/0002cls4.jpg
# A    CVI_newdataset/square3class/3/0002cls5.jpg
# A    CVI_newdataset/square3class/3/0003cls4.jpg
# A    CVI_newdataset/square3class/3/0003cls5.jpg
# A    CVI_newdataset/square3class/3/0004cls4.jpg
# A    CVI_newdataset/square3class/3/0004cls5.jpg
# A    CVI_newdataset/square3class/3/0005cls4.jpg
# A    CVI_newdataset/square3class/3/0005cls5.jpg
# A    CVI_newdataset/square3class/3/0006cls4.jpg
# A    CVI_newdataset/square3class/3/0006cls5.jpg
# A    CVI_newdataset/square3class/3/0007cls4.jpg
# A    CVI_newdataset/square3class/3/0007cls5.jpg
# A    CVI_newdataset/square3class/3/0008cls4.jpg
# A    CVI_newdataset/square3class/3/0008cls5.jpg
# A    CVI_newdataset/square3class/3/0009cls4.jpg
# A    CVI_newdataset/square3class/3/0009cls5.jpg
# A    CVI_newdataset/square3class/3/0010cls4.jpg
# A    CVI_newdataset/square3class/3/0010cls5.jpg
# A    CVI_newdataset/square3class/3/0011cls4.jpg
# A    CVI_newdataset/square3class/3/0011cls5.jpg
# A    CVI_newdataset/square3class/3/0012cls4.jpg
# A    CVI_newdataset/square3class/3/0012cls5.jpg
# A    CVI_newdataset/square3class/3/0013cls4.jpg
# A    CVI_newdataset/square3class/3/0013cls5.jpg
# A    CVI_newdataset/square3class/3/0014cls4.jpg
# A    CVI_newdataset/square3class/3/0014cls5.jpg
# A    CVI_newdataset/square3class/3/0015cls4.jpg
# A    CVI_newdataset/square3class/3/0015cls5.jpg
# A    CVI_newdataset/square3class/3/0016cls4.jpg
# A    CVI_newdataset/square3class/3/0016cls5.jpg
# A    CVI_newdataset/square3class/3/0017cls4.jpg
# A    CVI_newdataset/square3class/3/0017cls5.jpg
# A    CVI_newdataset/square3class/3/0018cls4.jpg
# A    CVI_newdataset/square3class/3/0018cls5.jpg
# A    CVI_newdataset/square3class/3/0019cls4.jpg
# A    CVI_newdataset/square3class/3/0019cls5.jpg
# A    CVI_newdataset/square3class/3/0020cls4.jpg
# A    CVI_newdataset/square3class/3/0020cls5.jpg
# A    CVI_newdataset/square3class/3/0021cls4.jpg
# A    CVI_newdataset/square3class/3/0021cls5.jpg
# A    CVI_newdataset/square3class/3/0022cls4.jpg
# A    CVI_newdataset/square3class/3/0022cls5.jpg
# A    CVI_newdataset/square3class/3/0023cls4.jpg
# A    CVI_newdataset/square3class/3/0023cls5.jpg
# A    CVI_newdataset/square3class/3/0024cls4.jpg
# A    CVI_newdataset/square3class/3/0024cls5.jpg
# A    CVI_newdataset/square3class/3/0025cls4.jpg
# A    CVI_newdataset/square3class/3/0025cls5.jpg
# A    CVI_newdataset/square3class/3/0026cls4.jpg
# A    CVI_newdataset/square3class/3/0026cls5.jpg
# A    CVI_newdataset/square3class/3/0027cls4.jpg
# A    CVI_newdataset/square3class/3/0027cls5.jpg
# A    CVI_newdataset/square3class/3/0028cls4.jpg
# A    CVI_newdataset/square3class/3/0028cls5.jpg
# A    CVI_newdataset/square3class/3/0029cls4.jpg
# A    CVI_newdataset/square3class/3/0029cls5.jpg
# A    CVI_newdataset/square3class/3/0030cls4.jpg
# A    CVI_newdataset/square3class/3/0030cls5.jpg
# A    CVI_newdataset/square3class/3/0031cls4.jpg
# A    CVI_newdataset/square3class/3/0031cls5.jpg
# A    CVI_newdataset/square3class/3/0032cls4.jpg
# A    CVI_newdataset/square3class/3/0032cls5.jpg
# A    CVI_newdataset/square3class/3/0033cls4.jpg
# A    CVI_newdataset/square3class/3/0033cls5.jpg
# A    CVI_newdataset/square3class/3/0034cls4.jpg
# A    CVI_newdataset/square3class/3/0034cls5.jpg
# A    CVI_newdataset/square3class/3/0035cls4.jpg
# A    CVI_newdataset/square3class/3/0035cls5.jpg
# A    CVI_newdataset/square3class/3/0036cls4.jpg
# A    CVI_newdataset/square3class/3/0036cls5.jpg
# A    CVI_newdataset/square3class/3/0037cls4.jpg
# A    CVI_newdataset/square3class/3/0037cls5.jpg
# A    CVI_newdataset/square3class/3/0038cls4.jpg
# A    CVI_newdataset/square3class/3/0038cls5.jpg
# A    CVI_newdataset/square3class/3/0039cls4.jpg
# A    CVI_newdataset/square3class/3/0039cls5.jpg
# A    CVI_newdataset/square3class/3/0040cls4.jpg
# A    CVI_newdataset/square3class/3/0040cls5.jpg
# A    CVI_newdataset/square3class/3/0041cls5.jpg
# A    CVI_newdataset/square3class/3/0042cls5.jpg
# A    CVI_newdataset/square3class/3/0043cls5.jpg
# A    CVI_newdataset/square3class/3/0044cls5.jpg
# A    CVI_newdataset/square3class/3/0045cls5.jpg
# A    CVI_newdataset/square3class/3/0046cls5.jpg
# A    CVI_newdataset/square3class/3/0048cls5.jpg
# A    CVI_newdataset/square3class/3/0049cls5.jpg
# A    CVI_newdataset/square3class/3/0050cls5.jpg
# A    CVI_newdataset/square3class/3/0051cls5.jpg
# A    CVI_newdataset/square3class/3/0052cls5.jpg
# A    CVI_newdataset/square3class/3/0053cls5.jpg
# A    CVI_newdataset/square3class/3/0054cls5.jpg
# A    CVI_newdataset/square3class/3/0055cls5.jpg
# A    CVI_newdataset/square3class/3/0056cls5.jpg
# A    CVI_newdataset/square3class/3/0057cls5.jpg
# A    CVI_newdataset/square3class/3/0058cls5.jpg
# A    CVI_newdataset/square3class/3/0059cls5.jpg
# A    CVI_newdataset/square3class/3/0060cls5.jpg
# A    CVI_newdataset/square3class/3/0061cls5.jpg
# A    CVI_newdataset/square3class/3/0062cls5.jpg
# A    CVI_newdataset/square3class/3/0063cls5.jpg
# A    CVI_newdataset/square3class/3/0064cls5.jpg
# A    CVI_newdataset/square3class/3/0065cls5.jpg
# A    CVI_newdataset/square3class/3/0066cls5.jpg
# A    CVI_newdataset/square5class
# A    CVI_newdataset/square5class/1
# A    CVI_newdataset/square5class/1/0001cls1.jpg
# A    CVI_newdataset/square5class/1/0002cls1.jpg
# A    CVI_newdataset/square5class/1/0003cls1.jpg
# A    CVI_newdataset/square5class/1/0004cls1.jpg
# A    CVI_newdataset/square5class/1/0005cls1.jpg
# A    CVI_newdataset/square5class/1/0006cls1.jpg
# A    CVI_newdataset/square5class/1/0007cls1.jpg
# A    CVI_newdataset/square5class/1/0008cls1.jpg
# A    CVI_newdataset/square5class/1/0009cls1.jpg
# A    CVI_newdataset/square5class/1/0010cls1.jpg
# A    CVI_newdataset/square5class/1/0011cls1.jpg
# A    CVI_newdataset/square5class/1/0012cls1.jpg
# A    CVI_newdataset/square5class/1/0013cls1.jpg
# A    CVI_newdataset/square5class/1/0014cls1.jpg
# A    CVI_newdataset/square5class/1/0015cls1.jpg
# A    CVI_newdataset/square5class/1/0016cls1.jpg
# A    CVI_newdataset/square5class/1/0017cls1.jpg
# A    CVI_newdataset/square5class/1/0018cls1.jpg
# A    CVI_newdataset/square5class/1/0019cls1.jpg
# A    CVI_newdataset/square5class/1/0020cls1.jpg
# A    CVI_newdataset/square5class/1/0021cls1.jpg
# A    CVI_newdataset/square5class/1/0022cls1.jpg
# A    CVI_newdataset/square5class/1/0023cls1.jpg
# A    CVI_newdataset/square5class/1/0024cls1.jpg
# A    CVI_newdataset/square5class/1/0025cls1.jpg
# A    CVI_newdataset/square5class/1/0026cls1.jpg
# A    CVI_newdataset/square5class/1/0027cls1.jpg
# A    CVI_newdataset/square5class/1/0028cls1.jpg
# A    CVI_newdataset/square5class/1/0029cls1.jpg
# A    CVI_newdataset/square5class/1/0030cls1.jpg
# A    CVI_newdataset/square5class/1/0031cls1.jpg
# A    CVI_newdataset/square5class/1/0032cls1.jpg
# A    CVI_newdataset/square5class/1/0033cls1.jpg
# A    CVI_newdataset/square5class/1/0034cls1.jpg
# A    CVI_newdataset/square5class/1/0035cls1.jpg
# A    CVI_newdataset/square5class/2
# A    CVI_newdataset/square5class/2/0001cls2.jpg
# A    CVI_newdataset/square5class/2/0002cls2.jpg
# A    CVI_newdataset/square5class/2/0003cls2.jpg
# A    CVI_newdataset/square5class/2/0004cls2.jpg
# A    CVI_newdataset/square5class/2/0005cls2.jpg
# A    CVI_newdataset/square5class/2/0006cls2.jpg
# A    CVI_newdataset/square5class/2/0007cls2.jpg
# A    CVI_newdataset/square5class/2/0008cls2.jpg
# A    CVI_newdataset/square5class/2/0009cls2.jpg
# A    CVI_newdataset/square5class/2/0010cls2.jpg
# A    CVI_newdataset/square5class/2/0011cls2.jpg
# A    CVI_newdataset/square5class/2/0012cls2.jpg
# A    CVI_newdataset/square5class/2/0013cls2.jpg
# A    CVI_newdataset/square5class/2/0014cls2.jpg
# A    CVI_newdataset/square5class/2/0015cls2.jpg
# A    CVI_newdataset/square5class/2/0016cls2.jpg
# A    CVI_newdataset/square5class/2/0017cls2.jpg
# A    CVI_newdataset/square5class/2/0018cls2.jpg
# A    CVI_newdataset/square5class/2/0019cls2.jpg
# A    CVI_newdataset/square5class/2/0020cls2.jpg
# A    CVI_newdataset/square5class/2/0021cls2.jpg
# A    CVI_newdataset/square5class/2/0022cls2.jpg
# A    CVI_newdataset/square5class/2/0023cls2.jpg
# A    CVI_newdataset/square5class/2/0024cls2.jpg
# A    CVI_newdataset/square5class/3
# A    CVI_newdataset/square5class/3/0001cls3.jpg
# A    CVI_newdataset/square5class/3/0002cls3.jpg
# A    CVI_newdataset/square5class/3/0003cls3.jpg
# A    CVI_newdataset/square5class/3/0004cls3.jpg
# A    CVI_newdataset/square5class/3/0005cls3.jpg
# A    CVI_newdataset/square5class/3/0006cls3.jpg
# A    CVI_newdataset/square5class/3/0007cls3.jpg
# A    CVI_newdataset/square5class/3/0008cls3.jpg
# A    CVI_newdataset/square5class/3/0009cls3.jpg
# A    CVI_newdataset/square5class/3/0010cls3.jpg
# A    CVI_newdataset/square5class/3/0011cls3.jpg
# A    CVI_newdataset/square5class/3/0012cls3.jpg
# A    CVI_newdataset/square5class/3/0013cls3.jpg
# A    CVI_newdataset/square5class/3/0014cls3.jpg
# A    CVI_newdataset/square5class/3/0015cls3.jpg
# A    CVI_newdataset/square5class/3/0016cls3.jpg
# A    CVI_newdataset/square5class/3/0017cls3.jpg
# A    CVI_newdataset/square5class/3/0018cls3.jpg
# A    CVI_newdataset/square5class/3/0019cls3.jpg
# A    CVI_newdataset/square5class/3/0020cls3.jpg
# A    CVI_newdataset/square5class/3/0021cls3.jpg
# A    CVI_newdataset/square5class/3/0022cls3.jpg
# A    CVI_newdataset/square5class/3/0023cls3.jpg
# A    CVI_newdataset/square5class/3/0024cls3.jpg
# A    CVI_newdataset/square5class/3/0025cls3.jpg
# A    CVI_newdataset/square5class/3/0026cls3.jpg
# A    CVI_newdataset/square5class/3/0027cls3.jpg
# A    CVI_newdataset/square5class/3/0028cls3.jpg
# A    CVI_newdataset/square5class/3/0029cls3.jpg
# A    CVI_newdataset/square5class/3/0030cls3.jpg
# A    CVI_newdataset/square5class/3/0031cls3.jpg
# A    CVI_newdataset/square5class/3/0032cls3.jpg
# A    CVI_newdataset/square5class/3/0033cls3.jpg
# A    CVI_newdataset/square5class/3/0034cls3.jpg
# A    CVI_newdataset/square5class/3/0035cls3.jpg
# A    CVI_newdataset/square5class/3/0036cls3.jpg
# A    CVI_newdataset/square5class/3/0037cls3.jpg
# A    CVI_newdataset/square5class/3/0038cls3.jpg
# A    CVI_newdataset/square5class/3/0039cls3.jpg
# A    CVI_newdataset/square5class/3/0040cls3.jpg
# A    CVI_newdataset/square5class/3/0041cls3.jpg
# A    CVI_newdataset/square5class/3/0042cls3.jpg
# A    CVI_newdataset/square5class/3/0043cls3.jpg
# A    CVI_newdataset/square5class/3/0044cls3.jpg
# A    CVI_newdataset/square5class/3/0045cls3.jpg
# A    CVI_newdataset/square5class/3/0046cls3.jpg
# A    CVI_newdataset/square5class/3/0047cls3.jpg
# A    CVI_newdataset/square5class/3/0048cls3.jpg
# A    CVI_newdataset/square5class/3/0049cls3.jpg
# A    CVI_newdataset/square5class/3/0050cls3.jpg
# A    CVI_newdataset/square5class/3/0051cls3.jpg
# A    CVI_newdataset/square5class/3/0052cls3.jpg
# A    CVI_newdataset/square5class/3/0053cls3.jpg
# A    CVI_newdataset/square5class/3/0054cls3.jpg
# A    CVI_newdataset/square5class/3/0055cls3.jpg
# A    CVI_newdataset/square5class/3/0056cls3.jpg
# A    CVI_newdataset/square5class/3/0057cls3.jpg
# A    CVI_newdataset/square5class/4
# A    CVI_newdataset/square5class/4/0001cls4.jpg
# A    CVI_newdataset/square5class/4/0002cls4.jpg
# A    CVI_newdataset/square5class/4/0003cls4.jpg
# A    CVI_newdataset/square5class/4/0004cls4.jpg
# A    CVI_newdataset/square5class/4/0005cls4.jpg
# A    CVI_newdataset/square5class/4/0006cls4.jpg
# A    CVI_newdataset/square5class/4/0007cls4.jpg
# A    CVI_newdataset/square5class/4/0008cls4.jpg
# A    CVI_newdataset/square5class/4/0009cls4.jpg
# A    CVI_newdataset/square5class/4/0010cls4.jpg
# A    CVI_newdataset/square5class/4/0011cls4.jpg
# A    CVI_newdataset/square5class/4/0012cls4.jpg
# A    CVI_newdataset/square5class/4/0013cls4.jpg
# A    CVI_newdataset/square5class/4/0014cls4.jpg
# A    CVI_newdataset/square5class/4/0015cls4.jpg
# A    CVI_newdataset/square5class/4/0016cls4.jpg
# A    CVI_newdataset/square5class/4/0017cls4.jpg
# A    CVI_newdataset/square5class/4/0018cls4.jpg
# A    CVI_newdataset/square5class/4/0019cls4.jpg
# A    CVI_newdataset/square5class/4/0020cls4.jpg
# A    CVI_newdataset/square5class/4/0021cls4.jpg
# A    CVI_newdataset/square5class/4/0022cls4.jpg
# A    CVI_newdataset/square5class/4/0023cls4.jpg
# A    CVI_newdataset/square5class/4/0024cls4.jpg
# A    CVI_newdataset/square5class/4/0025cls4.jpg
# A    CVI_newdataset/square5class/4/0026cls4.jpg
# A    CVI_newdataset/square5class/4/0027cls4.jpg
# A    CVI_newdataset/square5class/4/0028cls4.jpg
# A    CVI_newdataset/square5class/4/0029cls4.jpg
# A    CVI_newdataset/square5class/4/0030cls4.jpg
# A    CVI_newdataset/square5class/4/0031cls4.jpg
# A    CVI_newdataset/square5class/4/0032cls4.jpg
# A    CVI_newdataset/square5class/4/0033cls4.jpg
# A    CVI_newdataset/square5class/4/0034cls4.jpg
# A    CVI_newdataset/square5class/4/0035cls4.jpg
# A    CVI_newdataset/square5class/4/0036cls4.jpg
# A    CVI_newdataset/square5class/4/0037cls4.jpg
# A    CVI_newdataset/square5class/4/0038cls4.jpg
# A    CVI_newdataset/square5class/4/0039cls4.jpg
# A    CVI_newdataset/square5class/4/0040cls4.jpg
# A    CVI_newdataset/square5class/5
# A    CVI_newdataset/square5class/5/0001cls5.jpg
# A    CVI_newdataset/square5class/5/0002cls5.jpg
# A    CVI_newdataset/square5class/5/0003cls5.jpg
# A    CVI_newdataset/square5class/5/0004cls5.jpg
# A    CVI_newdataset/square5class/5/0005cls5.jpg
# A    CVI_newdataset/square5class/5/0006cls5.jpg
# A    CVI_newdataset/square5class/5/0007cls5.jpg
# A    CVI_newdataset/square5class/5/0008cls5.jpg
# A    CVI_newdataset/square5class/5/0009cls5.jpg
# A    CVI_newdataset/square5class/5/0010cls5.jpg
# A    CVI_newdataset/square5class/5/0011cls5.jpg
# A    CVI_newdataset/square5class/5/0012cls5.jpg
# A    CVI_newdataset/square5class/5/0013cls5.jpg
# A    CVI_newdataset/square5class/5/0014cls5.jpg
# A    CVI_newdataset/square5class/5/0015cls5.jpg
# A    CVI_newdataset/square5class/5/0016cls5.jpg
# A    CVI_newdataset/square5class/5/0017cls5.jpg
# A    CVI_newdataset/square5class/5/0018cls5.jpg
# A    CVI_newdataset/square5class/5/0019cls5.jpg
# A    CVI_newdataset/square5class/5/0020cls5.jpg
# A    CVI_newdataset/square5class/5/0021cls5.jpg
# A    CVI_newdataset/square5class/5/0022cls5.jpg
# A    CVI_newdataset/square5class/5/0023cls5.jpg
# A    CVI_newdataset/square5class/5/0024cls5.jpg
# A    CVI_newdataset/square5class/5/0025cls5.jpg
# A    CVI_newdataset/square5class/5/0026cls5.jpg
# A    CVI_newdataset/square5class/5/0027cls5.jpg
# A    CVI_newdataset/square5class/5/0028cls5.jpg
# A    CVI_newdataset/square5class/5/0029cls5.jpg
# A    CVI_newdataset/square5class/5/0030cls5.jpg
# A    CVI_newdataset/square5class/5/0031cls5.jpg
# A    CVI_newdataset/square5class/5/0032cls5.jpg
# A    CVI_newdataset/square5class/5/0033cls5.jpg
# A    CVI_newdataset/square5class/5/0034cls5.jpg
# A    CVI_newdataset/square5class/5/0035cls5.jpg
# A    CVI_newdataset/square5class/5/0036cls5.jpg
# A    CVI_newdataset/square5class/5/0037cls5.jpg
# A    CVI_newdataset/square5class/5/0038cls5.jpg
# A    CVI_newdataset/square5class/5/0039cls5.jpg
# A    CVI_newdataset/square5class/5/0040cls5.jpg
# A    CVI_newdataset/square5class/5/0041cls5.jpg
# A    CVI_newdataset/square5class/5/0042cls5.jpg
# A    CVI_newdataset/square5class/5/0043cls5.jpg
# A    CVI_newdataset/square5class/5/0044cls5.jpg
# A    CVI_newdataset/square5class/5/0045cls5.jpg
# A    CVI_newdataset/square5class/5/0046cls5.jpg
# A    CVI_newdataset/square5class/5/0048cls5.jpg
# A    CVI_newdataset/square5class/5/0049cls5.jpg
# A    CVI_newdataset/square5class/5/0050cls5.jpg
# A    CVI_newdataset/square5class/5/0051cls5.jpg
# A    CVI_newdataset/square5class/5/0052cls5.jpg
# A    CVI_newdataset/square5class/5/0053cls5.jpg
# A    CVI_newdataset/square5class/5/0054cls5.jpg
# A    CVI_newdataset/square5class/5/0055cls5.jpg
# A    CVI_newdataset/square5class/5/0056cls5.jpg
# A    CVI_newdataset/square5class/5/0057cls5.jpg
# A    CVI_newdataset/square5class/5/0058cls5.jpg
# A    CVI_newdataset/square5class/5/0059cls5.jpg
# A    CVI_newdataset/square5class/5/0060cls5.jpg
# A    CVI_newdataset/square5class/5/0061cls5.jpg
# A    CVI_newdataset/square5class/5/0062cls5.jpg
# A    CVI_newdataset/square5class/5/0063cls5.jpg
# A    CVI_newdataset/square5class/5/0064cls5.jpg
# A    CVI_newdataset/square5class/5/0065cls5.jpg
# A    CVI_newdataset/square5class/5/0066cls5.jpg
# Checked out revision 3.

# %%
from glob import glob
import numpy as np
import os
import shutil
import matplotlib.pyplot as plt
import math
from skimage.io import imread
import cv2 as cv2
from tqdm import tqdm

# %%
data_filtered = "/content/CVI_newdataset/square3class"
classes = ['1', '2', '3']

# %%
class1images = glob(data_filtered+'/'+'1'+'/'+'*')
class2images = glob(data_filtered+'/'+'2'+'/'+'*')
class3images = glob(data_filtered+'/'+'3'+'/'+'*')

# %%
#train val test split

# class_1 = os.listdir(data_filtered+'/1')
# class_2 = os.listdir(data_filtered+'/2')
# class_3 = os.listdir(data_filtered+'/3')

# for i in range(1,4):
#     for t in ["train", "test"]:
#         !mkdir -p /content/data/CVI-img-datasets/filtered/{t}/{i}/

# base_path = data_filtered
# for i in range(0, len(class_1)):
#   filename = class_1[i]
#   if i <= 45:
#     shutil.copy(f"{base_path}/1/{filename}", f"{base_path}/train/1/{filename}")
#   else:
#     shutil.copy(f"{base_path}/1/{filename}", f"{base_path}/test/1/{filename}")

# for i in range(0, len(class_2)):
#   filename = class_2[i]
#   if i <= 43:
#     shutil.copy(f"{base_path}/2/{filename}", f"{base_path}/train/2/{filename}")
#   else:
#     shutil.copy(f"{base_path}/2/{filename}", f"{base_path}/test/2/{filename}")

# for i in range(0, len(class_3)):
#   filename = class_3[i]
#   if i <= 91:
#     shutil.copy(f"{base_path}/3/{filename}", f"{base_path}/train/3/{filename}")
#   else:
#     shutil.copy(f"{base_path}/3/{filename}", f"{base_path}/test/3/{filename}")

# %%
len(class1images), len(class2images), len(class3images)
# Out:
# (59, 57, 105)

# %%
#load image paths
def load_images(paths):
    tmp = []
    for path in paths:
        tmp.append(imread(path))
    return tmp

# %%
#plot images
def plot_any(arr, title = ''):
    plt.figure(figsize = (15, 25))
    for i in range(len(arr)):
        plt.subplot(1,len(arr),i + 1)
        plt.title(title)
        plt.imshow(arr[i]);

# %%
load_class1images = load_images(class1images[:5])
load_class2images = load_images(class2images[:5])
load_class3images = load_images(class3images[:5])

# %%
plot_any(load_class1images, 'class 0')

# %%
plot_any(load_class2images, 'class 1')

# %%
plot_any(load_class3images, 'class 2')

# %%
cv2.__version__
# Out:
# '4.5.5'

# %%
batch_size = 16
img_height = 256
img_width = 256

# %%
data_path = '/content/CVI_newdataset/square3class'

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_path,
  validation_split=0.3,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 221 files belonging to 3 classes.
# Using 155 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_path,
  validation_split=0.3,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 221 files belonging to 3 classes.
# Using 66 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['1', '2', '3']

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (16, 256, 256, 3)
# (16,)

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(32, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 256, 256, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 128)               8388736
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 8,416,547
# Trainable params: 8,416,547
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 14s 145ms/step - loss: 1.1199 - accuracy: 0.3742 - val_loss: 1.0727 - val_accuracy: 0.4394
# Epoch 2/10
# 10/10 [==============================] - 1s 80ms/step - loss: 0.9782 - accuracy: 0.5161 - val_loss: 1.0968 - val_accuracy: 0.4545
# Epoch 3/10
# 10/10 [==============================] - 1s 73ms/step - loss: 0.8157 - accuracy: 0.6581 - val_loss: 1.1063 - val_accuracy: 0.4242
# Epoch 4/10
# 10/10 [==============================] - 1s 71ms/step - loss: 0.6548 - accuracy: 0.7097 - val_loss: 1.1448 - val_accuracy: 0.5000
# Epoch 5/10
# 10/10 [==============================] - 1s 71ms/step - loss: 0.4122 - accuracy: 0.8645 - val_loss: 1.5466 - val_accuracy: 0.5303
# Epoch 6/10
# 10/10 [==============================] - 1s 73ms/step - loss: 0.4796 - accuracy: 0.7871 - val_loss: 1.7275 - val_accuracy: 0.4242
# Epoch 7/10
# 10/10 [==============================] - 1s 71ms/step - loss: 0.2687 - accuracy: 0.8839 - val_loss: 1.2709 - val_accuracy: 0.5606
# Epoch 8/10
# 10/10 [==============================] - 1s 70ms/step - loss: 0.1551 - accuracy: 0.9548 - val_loss: 1.6559 - val_accuracy: 0.5455
# Epoch 9/10
# 10/10 [==============================] - 1s 71ms/step - loss: 0.1004 - accuracy: 0.9742 - val_loss: 1.7409 - val_accuracy: 0.5455
# Epoch 10/10
# 10/10 [==============================] - 1s 70ms/step - loss: 0.0504 - accuracy: 0.9935 - val_loss: 2.3789 - val_accuracy: 0.5758

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Data augmentation

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# Dropout

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 256, 256, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 128, 128, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 32)      4640
#
#  max_pooling2d_4 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 32, 32, 64)        0
#
#  flatten_1 (Flatten)         (None, 65536)             0
#
#  dense_3 (Dense)             (None, 128)               8388736
#
#  dense_4 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 8,412,707
# Trainable params: 8,412,707
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 100
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 3s 103ms/step - loss: 1.5813 - accuracy: 0.4065 - val_loss: 1.1067 - val_accuracy: 0.1818
# Epoch 2/100
# 10/10 [==============================] - 1s 78ms/step - loss: 1.0689 - accuracy: 0.4710 - val_loss: 1.1030 - val_accuracy: 0.4394
# Epoch 3/100
# 10/10 [==============================] - 1s 77ms/step - loss: 1.0471 - accuracy: 0.4903 - val_loss: 1.0922 - val_accuracy: 0.4394
# Epoch 4/100
# 10/10 [==============================] - 1s 77ms/step - loss: 1.0341 - accuracy: 0.4903 - val_loss: 1.0793 - val_accuracy: 0.4394
# Epoch 5/100
# 10/10 [==============================] - 1s 77ms/step - loss: 1.0269 - accuracy: 0.4903 - val_loss: 1.0708 - val_accuracy: 0.4394
# Epoch 6/100
# 10/10 [==============================] - 1s 77ms/step - loss: 1.0192 - accuracy: 0.4903 - val_loss: 1.0709 - val_accuracy: 0.4394
# Epoch 7/100
# 10/10 [==============================] - 1s 77ms/step - loss: 1.0326 - accuracy: 0.4903 - val_loss: 1.0609 - val_accuracy: 0.4394
# Epoch 8/100
# 10/10 [==============================] - 1s 77ms/step - loss: 1.0048 - accuracy: 0.4903 - val_loss: 1.0215 - val_accuracy: 0.4545
# Epoch 9/100
# 10/10 [==============================] - 1s 77ms/step - loss: 1.0024 - accuracy: 0.5613 - val_loss: 1.0078 - val_accuracy: 0.4697
# Epoch 10/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.9800 - accuracy: 0.5871 - val_loss: 1.0078 - val_accuracy: 0.4848
# Epoch 11/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.9651 - accuracy: 0.5871 - val_loss: 1.0047 - val_accuracy: 0.5152
# Epoch 12/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.9252 - accuracy: 0.5742 - val_loss: 1.1696 - val_accuracy: 0.4394
# Epoch 13/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.9539 - accuracy: 0.5871 - val_loss: 0.9690 - val_accuracy: 0.4697
# Epoch 14/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.9047 - accuracy: 0.6452 - val_loss: 1.0576 - val_accuracy: 0.4242
# Epoch 15/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.8738 - accuracy: 0.5935 - val_loss: 0.8547 - val_accuracy: 0.6364
# Epoch 16/100
# 10/10 [==============================] - 1s 86ms/step - loss: 0.7636 - accuracy: 0.6839 - val_loss: 1.0368 - val_accuracy: 0.5000
# Epoch 17/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.9587 - accuracy: 0.5419 - val_loss: 0.8587 - val_accuracy: 0.5909
# Epoch 18/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.8971 - accuracy: 0.6323 - val_loss: 0.8721 - val_accuracy: 0.5758
# Epoch 19/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.8538 - accuracy: 0.6774 - val_loss: 0.9237 - val_accuracy: 0.5303
# Epoch 20/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.7880 - accuracy: 0.6452 - val_loss: 0.7938 - val_accuracy: 0.5455
# Epoch 21/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.7977 - accuracy: 0.6452 - val_loss: 0.8306 - val_accuracy: 0.5606
# Epoch 22/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.8006 - accuracy: 0.6581 - val_loss: 0.8181 - val_accuracy: 0.5606
# Epoch 23/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.7574 - accuracy: 0.7032 - val_loss: 0.7741 - val_accuracy: 0.5455
# Epoch 24/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.6967 - accuracy: 0.6645 - val_loss: 0.6976 - val_accuracy: 0.6061
# Epoch 25/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.7006 - accuracy: 0.7290 - val_loss: 0.9025 - val_accuracy: 0.5303
# Epoch 26/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.7431 - accuracy: 0.7097 - val_loss: 0.9452 - val_accuracy: 0.5152
# Epoch 27/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.7794 - accuracy: 0.6774 - val_loss: 0.8532 - val_accuracy: 0.5606
# Epoch 28/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.6500 - accuracy: 0.7161 - val_loss: 0.8867 - val_accuracy: 0.5455
# Epoch 29/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.6609 - accuracy: 0.7419 - val_loss: 0.7780 - val_accuracy: 0.5455
# Epoch 30/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.6930 - accuracy: 0.7419 - val_loss: 1.1211 - val_accuracy: 0.4394
# Epoch 31/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.8361 - accuracy: 0.6258 - val_loss: 0.9170 - val_accuracy: 0.5000
# Epoch 32/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.7263 - accuracy: 0.7484 - val_loss: 0.7919 - val_accuracy: 0.5758
# Epoch 33/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.7110 - accuracy: 0.7097 - val_loss: 0.8568 - val_accuracy: 0.5303
# Epoch 34/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.6439 - accuracy: 0.7484 - val_loss: 0.7116 - val_accuracy: 0.6515
# Epoch 35/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.6314 - accuracy: 0.6903 - val_loss: 0.7363 - val_accuracy: 0.6061
# Epoch 36/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.6329 - accuracy: 0.7548 - val_loss: 0.8300 - val_accuracy: 0.5909
# Epoch 37/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.6452 - accuracy: 0.7355 - val_loss: 0.8761 - val_accuracy: 0.5606
# Epoch 38/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.6043 - accuracy: 0.7290 - val_loss: 0.8142 - val_accuracy: 0.6212
# Epoch 39/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.5810 - accuracy: 0.8000 - val_loss: 0.8832 - val_accuracy: 0.5606
# Epoch 40/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.6079 - accuracy: 0.7290 - val_loss: 0.8305 - val_accuracy: 0.5758
# Epoch 41/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.6135 - accuracy: 0.7419 - val_loss: 0.7342 - val_accuracy: 0.6061
# Epoch 42/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.5070 - accuracy: 0.8194 - val_loss: 0.8172 - val_accuracy: 0.5758
# Epoch 43/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.5620 - accuracy: 0.8129 - val_loss: 0.7659 - val_accuracy: 0.6212
# Epoch 44/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.5622 - accuracy: 0.7742 - val_loss: 1.0186 - val_accuracy: 0.5303
# Epoch 45/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.5162 - accuracy: 0.7871 - val_loss: 0.8007 - val_accuracy: 0.5909
# Epoch 46/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.5285 - accuracy: 0.7871 - val_loss: 0.8144 - val_accuracy: 0.6212
# Epoch 47/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.5170 - accuracy: 0.8065 - val_loss: 0.7014 - val_accuracy: 0.6515
# Epoch 48/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.5048 - accuracy: 0.7935 - val_loss: 0.7660 - val_accuracy: 0.6061
# Epoch 49/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.4838 - accuracy: 0.7613 - val_loss: 0.7772 - val_accuracy: 0.6212
# Epoch 50/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.4580 - accuracy: 0.7935 - val_loss: 0.7709 - val_accuracy: 0.5909
# Epoch 51/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.5073 - accuracy: 0.8065 - val_loss: 0.8272 - val_accuracy: 0.6212
# Epoch 52/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.4471 - accuracy: 0.8323 - val_loss: 0.8684 - val_accuracy: 0.6061
# Epoch 53/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.4176 - accuracy: 0.8387 - val_loss: 0.8576 - val_accuracy: 0.5758
# Epoch 54/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.5069 - accuracy: 0.7935 - val_loss: 0.8842 - val_accuracy: 0.5455
# Epoch 55/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.4462 - accuracy: 0.8323 - val_loss: 0.8069 - val_accuracy: 0.5758
# Epoch 56/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.4522 - accuracy: 0.8323 - val_loss: 0.7674 - val_accuracy: 0.6061
# Epoch 57/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.4544 - accuracy: 0.8194 - val_loss: 0.8914 - val_accuracy: 0.5909
# Epoch 58/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.3766 - accuracy: 0.8774 - val_loss: 0.7760 - val_accuracy: 0.6061
# Epoch 59/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.3512 - accuracy: 0.8516 - val_loss: 0.7091 - val_accuracy: 0.6212
# Epoch 60/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.3825 - accuracy: 0.8452 - val_loss: 0.6503 - val_accuracy: 0.6515
# Epoch 61/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.4922 - accuracy: 0.7806 - val_loss: 0.7952 - val_accuracy: 0.6212
# Epoch 62/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.3846 - accuracy: 0.8645 - val_loss: 0.8312 - val_accuracy: 0.6061
# Epoch 63/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.3764 - accuracy: 0.8452 - val_loss: 0.8889 - val_accuracy: 0.6212
# Epoch 64/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.4814 - accuracy: 0.7935 - val_loss: 0.7478 - val_accuracy: 0.6212
# Epoch 65/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.3896 - accuracy: 0.8323 - val_loss: 0.7396 - val_accuracy: 0.6667
# Epoch 66/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.3614 - accuracy: 0.8710 - val_loss: 0.9430 - val_accuracy: 0.6061
# Epoch 67/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.4044 - accuracy: 0.8258 - val_loss: 0.8245 - val_accuracy: 0.6667
# Epoch 68/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.4301 - accuracy: 0.8194 - val_loss: 0.8629 - val_accuracy: 0.6212
# Epoch 69/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.3352 - accuracy: 0.8645 - val_loss: 0.7972 - val_accuracy: 0.6212
# Epoch 70/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.3609 - accuracy: 0.8581 - val_loss: 0.6739 - val_accuracy: 0.6970
# Epoch 71/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.3555 - accuracy: 0.8452 - val_loss: 0.7647 - val_accuracy: 0.6667
# Epoch 72/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.3333 - accuracy: 0.8710 - val_loss: 0.7710 - val_accuracy: 0.6970
# Epoch 73/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.3693 - accuracy: 0.8452 - val_loss: 0.8097 - val_accuracy: 0.6364
# Epoch 74/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.3511 - accuracy: 0.8581 - val_loss: 0.8516 - val_accuracy: 0.5909
# Epoch 75/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.3441 - accuracy: 0.8839 - val_loss: 0.8926 - val_accuracy: 0.6061
# Epoch 76/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.3601 - accuracy: 0.8710 - val_loss: 0.6865 - val_accuracy: 0.7576
# Epoch 77/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.3577 - accuracy: 0.8839 - val_loss: 0.9138 - val_accuracy: 0.5909
# Epoch 78/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.3118 - accuracy: 0.8710 - val_loss: 0.8772 - val_accuracy: 0.6970
# Epoch 79/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.3719 - accuracy: 0.8516 - val_loss: 0.9938 - val_accuracy: 0.5758
# Epoch 80/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.3203 - accuracy: 0.8839 - val_loss: 1.0636 - val_accuracy: 0.6212
# Epoch 81/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.3352 - accuracy: 0.8645 - val_loss: 1.2392 - val_accuracy: 0.5303
# Epoch 82/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.3324 - accuracy: 0.8645 - val_loss: 1.1542 - val_accuracy: 0.5606
# Epoch 83/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.3952 - accuracy: 0.8516 - val_loss: 1.2480 - val_accuracy: 0.5000
# Epoch 84/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.4019 - accuracy: 0.8387 - val_loss: 0.8422 - val_accuracy: 0.6364
# Epoch 85/100
# 10/10 [==============================] - 1s 94ms/step - loss: 0.3794 - accuracy: 0.8581 - val_loss: 0.6830 - val_accuracy: 0.6515
# Epoch 86/100
# 10/10 [==============================] - 2s 118ms/step - loss: 0.3570 - accuracy: 0.8581 - val_loss: 0.8011 - val_accuracy: 0.5909
# Epoch 87/100
# 10/10 [==============================] - 2s 133ms/step - loss: 0.3409 - accuracy: 0.8774 - val_loss: 0.6829 - val_accuracy: 0.7273
# Epoch 88/100
# 10/10 [==============================] - 2s 133ms/step - loss: 0.2895 - accuracy: 0.9032 - val_loss: 0.9627 - val_accuracy: 0.6364
# Epoch 89/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.2586 - accuracy: 0.8968 - val_loss: 0.9207 - val_accuracy: 0.6212
# Epoch 90/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.4017 - accuracy: 0.8516 - val_loss: 0.7078 - val_accuracy: 0.6515
# Epoch 91/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.2964 - accuracy: 0.8903 - val_loss: 0.6457 - val_accuracy: 0.7121
# Epoch 92/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.2957 - accuracy: 0.8839 - val_loss: 0.7784 - val_accuracy: 0.6970
# Epoch 93/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.2909 - accuracy: 0.8839 - val_loss: 1.0723 - val_accuracy: 0.6061
# Epoch 94/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.3419 - accuracy: 0.8645 - val_loss: 0.8237 - val_accuracy: 0.6667
# Epoch 95/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.2304 - accuracy: 0.9226 - val_loss: 0.8083 - val_accuracy: 0.6212
# Epoch 96/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.2946 - accuracy: 0.8968 - val_loss: 0.7855 - val_accuracy: 0.6364
# Epoch 97/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.2147 - accuracy: 0.9032 - val_loss: 0.8407 - val_accuracy: 0.6667
# Epoch 98/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.2816 - accuracy: 0.8774 - val_loss: 0.7953 - val_accuracy: 0.6818
# Epoch 99/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.2271 - accuracy: 0.8968 - val_loss: 0.8581 - val_accuracy: 0.6667
# Epoch 100/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.2978 - accuracy: 0.8903 - val_loss: 0.8864 - val_accuracy: 0.6364

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
opt = keras.optimizers.Adam(learning_rate=0.1)

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 2s 105ms/step - loss: 1.1328 - accuracy: 0.4387 - val_loss: 1.0778 - val_accuracy: 0.4394
# Epoch 2/50
# 10/10 [==============================] - 1s 79ms/step - loss: 1.0562 - accuracy: 0.4903 - val_loss: 1.0790 - val_accuracy: 0.4394
# Epoch 3/50
# 10/10 [==============================] - 1s 77ms/step - loss: 1.0660 - accuracy: 0.4903 - val_loss: 1.0828 - val_accuracy: 0.4394
# Epoch 4/50
# 10/10 [==============================] - 1s 78ms/step - loss: 1.0469 - accuracy: 0.4903 - val_loss: 1.0842 - val_accuracy: 0.4394
# Epoch 5/50
# 10/10 [==============================] - 1s 78ms/step - loss: 1.0148 - accuracy: 0.4903 - val_loss: 1.0583 - val_accuracy: 0.4394
# Epoch 6/50
# 10/10 [==============================] - 1s 76ms/step - loss: 0.9995 - accuracy: 0.4903 - val_loss: 1.0379 - val_accuracy: 0.4394
# Epoch 7/50
# 10/10 [==============================] - 1s 78ms/step - loss: 1.0089 - accuracy: 0.4903 - val_loss: 0.9848 - val_accuracy: 0.4394
# Epoch 8/50
# 10/10 [==============================] - 1s 78ms/step - loss: 1.0044 - accuracy: 0.4903 - val_loss: 0.9872 - val_accuracy: 0.4394
# Epoch 9/50
# 10/10 [==============================] - 1s 76ms/step - loss: 0.9866 - accuracy: 0.4903 - val_loss: 0.9884 - val_accuracy: 0.4394
# Epoch 10/50
# 10/10 [==============================] - 1s 78ms/step - loss: 0.9979 - accuracy: 0.5032 - val_loss: 1.0306 - val_accuracy: 0.4848
# Epoch 11/50
# 10/10 [==============================] - 1s 77ms/step - loss: 0.9703 - accuracy: 0.5484 - val_loss: 1.0677 - val_accuracy: 0.4394
# Epoch 12/50
# 10/10 [==============================] - 1s 78ms/step - loss: 0.9730 - accuracy: 0.5613 - val_loss: 1.0607 - val_accuracy: 0.5000
# Epoch 13/50
# 10/10 [==============================] - 1s 78ms/step - loss: 0.9430 - accuracy: 0.5484 - val_loss: 0.9591 - val_accuracy: 0.4848
# Epoch 14/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.9320 - accuracy: 0.5871 - val_loss: 0.9642 - val_accuracy: 0.5303
# Epoch 15/50
# 10/10 [==============================] - 1s 78ms/step - loss: 0.9211 - accuracy: 0.6000 - val_loss: 0.9965 - val_accuracy: 0.5152
# Epoch 16/50
# 10/10 [==============================] - 1s 78ms/step - loss: 0.9322 - accuracy: 0.5871 - val_loss: 0.9207 - val_accuracy: 0.5303
# Epoch 17/50
# 10/10 [==============================] - 1s 78ms/step - loss: 0.8682 - accuracy: 0.5935 - val_loss: 0.9947 - val_accuracy: 0.5455
# Epoch 18/50
# 10/10 [==============================] - 1s 76ms/step - loss: 0.8629 - accuracy: 0.6000 - val_loss: 0.9147 - val_accuracy: 0.5606
# Epoch 19/50
# 10/10 [==============================] - 1s 77ms/step - loss: 0.8128 - accuracy: 0.6516 - val_loss: 0.9199 - val_accuracy: 0.5758
# Epoch 20/50
# 10/10 [==============================] - 1s 76ms/step - loss: 0.7903 - accuracy: 0.6645 - val_loss: 0.8462 - val_accuracy: 0.5909
# Epoch 21/50
# 10/10 [==============================] - 1s 78ms/step - loss: 0.8434 - accuracy: 0.6323 - val_loss: 0.9049 - val_accuracy: 0.5909
# Epoch 22/50
# 10/10 [==============================] - 1s 78ms/step - loss: 0.8084 - accuracy: 0.6710 - val_loss: 0.7973 - val_accuracy: 0.5909
# Epoch 23/50
# 10/10 [==============================] - 1s 78ms/step - loss: 0.6978 - accuracy: 0.7097 - val_loss: 0.9531 - val_accuracy: 0.5758
# Epoch 24/50
# 10/10 [==============================] - 1s 77ms/step - loss: 0.7270 - accuracy: 0.7290 - val_loss: 0.9020 - val_accuracy: 0.4848
# Epoch 25/50
# 10/10 [==============================] - 1s 78ms/step - loss: 0.7255 - accuracy: 0.6774 - val_loss: 0.8675 - val_accuracy: 0.5758
# Epoch 26/50
# 10/10 [==============================] - 1s 78ms/step - loss: 0.6550 - accuracy: 0.7097 - val_loss: 0.7398 - val_accuracy: 0.6515
# Epoch 27/50
# 10/10 [==============================] - 1s 77ms/step - loss: 0.6579 - accuracy: 0.7613 - val_loss: 0.7023 - val_accuracy: 0.6667
# Epoch 28/50
# 10/10 [==============================] - 1s 78ms/step - loss: 0.6366 - accuracy: 0.7613 - val_loss: 0.7171 - val_accuracy: 0.6212
# Epoch 29/50
# 10/10 [==============================] - 1s 77ms/step - loss: 0.6513 - accuracy: 0.6839 - val_loss: 0.7771 - val_accuracy: 0.5909
# Epoch 30/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.6143 - accuracy: 0.7290 - val_loss: 0.7198 - val_accuracy: 0.6515
# Epoch 31/50
# 10/10 [==============================] - 1s 79ms/step - loss: 0.6146 - accuracy: 0.7419 - val_loss: 0.6476 - val_accuracy: 0.7273
# Epoch 32/50
# 10/10 [==============================] - 1s 79ms/step - loss: 0.5022 - accuracy: 0.8000 - val_loss: 0.6341 - val_accuracy: 0.7273
# Epoch 33/50
# 10/10 [==============================] - 1s 77ms/step - loss: 0.5892 - accuracy: 0.7484 - val_loss: 0.6614 - val_accuracy: 0.6970
# Epoch 34/50
# 10/10 [==============================] - 2s 124ms/step - loss: 0.5668 - accuracy: 0.7677 - val_loss: 0.7781 - val_accuracy: 0.5909
# Epoch 35/50
# 10/10 [==============================] - 1s 77ms/step - loss: 0.5408 - accuracy: 0.7613 - val_loss: 0.6999 - val_accuracy: 0.5909
# Epoch 36/50
# 10/10 [==============================] - 1s 78ms/step - loss: 0.4742 - accuracy: 0.8387 - val_loss: 1.0346 - val_accuracy: 0.5758
# Epoch 37/50
# 10/10 [==============================] - 1s 80ms/step - loss: 0.5358 - accuracy: 0.7484 - val_loss: 1.1278 - val_accuracy: 0.5758
# Epoch 38/50
# 10/10 [==============================] - 1s 79ms/step - loss: 0.5483 - accuracy: 0.7484 - val_loss: 0.6631 - val_accuracy: 0.6818
# Epoch 39/50
# 10/10 [==============================] - 2s 88ms/step - loss: 0.4638 - accuracy: 0.8194 - val_loss: 0.6328 - val_accuracy: 0.6970
# Epoch 40/50
# 10/10 [==============================] - 1s 77ms/step - loss: 0.5212 - accuracy: 0.7548 - val_loss: 0.6775 - val_accuracy: 0.6970
# Epoch 41/50
# 10/10 [==============================] - 1s 79ms/step - loss: 0.5465 - accuracy: 0.7677 - val_loss: 0.6098 - val_accuracy: 0.7273
# Epoch 42/50
# 10/10 [==============================] - 1s 78ms/step - loss: 0.4696 - accuracy: 0.8452 - val_loss: 0.7117 - val_accuracy: 0.6364
# Epoch 43/50
# 10/10 [==============================] - 1s 79ms/step - loss: 0.4965 - accuracy: 0.7806 - val_loss: 0.7679 - val_accuracy: 0.6364
# Epoch 44/50
# 10/10 [==============================] - 1s 80ms/step - loss: 0.5091 - accuracy: 0.8000 - val_loss: 0.7732 - val_accuracy: 0.6515
# Epoch 45/50
# 10/10 [==============================] - 1s 79ms/step - loss: 0.4949 - accuracy: 0.8065 - val_loss: 0.7400 - val_accuracy: 0.6818
# Epoch 46/50
# 10/10 [==============================] - 1s 78ms/step - loss: 0.4772 - accuracy: 0.8452 - val_loss: 0.6906 - val_accuracy: 0.6667
# Epoch 47/50
# 10/10 [==============================] - 1s 81ms/step - loss: 0.4459 - accuracy: 0.8129 - val_loss: 0.6570 - val_accuracy: 0.6818
# Epoch 48/50
# 10/10 [==============================] - 1s 80ms/step - loss: 0.4433 - accuracy: 0.8000 - val_loss: 0.8301 - val_accuracy: 0.6667
# Epoch 49/50
# 10/10 [==============================] - 1s 80ms/step - loss: 0.4540 - accuracy: 0.8129 - val_loss: 0.6294 - val_accuracy: 0.7121
# Epoch 50/50
# 10/10 [==============================] - 1s 80ms/step - loss: 0.3757 - accuracy: 0.8516 - val_loss: 0.7431 - val_accuracy: 0.6970

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Predict on new data

# %%
# sunflower_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/592px-Red_sunflower.jpg"
# sunflower_path = tf.keras.utils.get_file('Red_sunflower', origin=sunflower_url)

# img = tf.keras.utils.load_img(
#     sunflower_path, target_size=(img_height, img_width)
# )
# img_array = tf.keras.utils.img_to_array(img)
# img_array = tf.expand_dims(img_array, 0) # Create a batch

# predictions = model.predict(img_array)
# score = tf.nn.softmax(predictions[0])

# print(
#     "This image most likely belongs to {} with a {:.2f} percent confidence."
#     .format(class_names[np.argmax(score)], 100 * np.max(score))
# )
